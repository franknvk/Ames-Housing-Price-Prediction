# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet

from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


import warnings
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv("datasets/train.csv")

# %%
train_df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
# 3          NaN        0       4    2010        WD      174000
# 4          NaN        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
train_df.columns = [column.lower() for column in train_df.columns]
train_df.columns = [column.replace(' ','_') for column in train_df.columns]
train_df.head()
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   lot_shape land_contour  ... screen_porch pool_area pool_qc fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   misc_feature misc_val mo_sold yr_sold  sale_type  saleprice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
# 3          NaN        0       4    2010        WD      174000
# 4          NaN        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Neighborhood Dataframe

# %%
stonebr_df = train_df[(train_df['neighborhood'] == 'StoneBr')]
stonebr_nulls = stonebr_df.isna().sum().sort_values(ascending=False)
stonebr_nulls[stonebr_nulls > 0]
# Out:
# alley           38
# misc_feature    38
# fence           38
# pool_qc         38
# fireplace_qu     9
# lot_frontage     4
# dtype: int64

# %%
#drop empty features == ['Alley', 'Misc Feature', 'Fence', 'Pool QC']
stonebr_df = stonebr_df.drop(columns = ['alley', 'misc_feature', 'fence', 'pool_qc'])

# %%
#NaN values corresponde to no value, replace with 0 ['Fireplace Qu', 'Lot Frontage']
stonebr_df = stonebr_df.dropna(0)

# %% [markdown]
# ### Test Train Split

# %%
X = stonebr_df.drop(columns = 'saleprice')
y = stonebr_df[['saleprice','id']]

# %% [markdown]
# ### Split DataFrame Based on Type of Feature

# %%
#split the data based on type to effectivly explore,impute,and encode if needed. Drop target featurer

#categorical features
numeric_train_df = X.select_dtypes(include = ['int','float']).sort_index()

#categorical features
categorical_train_df =  X.select_dtypes(include = ['object']).sort_index()

# %% [markdown]
# # Numeric Features

# %%
#remove ID and PID, put into own DF
id_train_df = numeric_train_df[['id','pid']]

numeric_train_df = numeric_train_df.drop(columns = ['id','pid'])

# %%
numeric_null = numeric_train_df.isna().sum().sort_values(ascending = False)
numeric_null[numeric_null > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# #### Numeric categories that could mean 0 for NA

# %% [markdown]
# ## Standard Scalar

# %%
ss = StandardScaler()

# %%
scaled_numeric_train_df = ss.fit_transform(numeric_train_df)
scaled_numeric_train_df = pd.DataFrame(scaled_numeric_train_df,index = numeric_train_df.index, columns=numeric_train_df.columns)

# %%
scaled_numeric_train_df
# Out:
#       ms_subclass  lot_frontage  lot_area  overall_qual  overall_cond  \
# 21       1.175949     -1.300412 -0.732817     -0.810443     -0.267261
# 81      -1.229402     -0.050326  0.273760      0.476731     -0.267261
# 100     -1.229402     -0.593842  0.100676      0.476731     -0.267261
# 138     -0.267261     -0.213380  0.328459      1.763906     -0.267261
# 151     -0.267261      1.145410  0.156744      0.476731     -0.267261
# 189     -0.267261      0.982355 -0.152959     -0.810443     -0.267261
# 190     -0.267261     -0.267732  0.153919      0.476731     -0.267261
# 227     -0.267261      0.710597 -0.259103      0.476731     -0.267261
# 246      2.138090     -1.083006 -0.763462     -2.097618      4.543441
# 317     -0.267261     -0.050326 -0.165456      0.476731     -0.267261
# 429      1.175949     -1.246061 -0.755844     -0.810443     -0.267261
# 458      1.175949     -1.354764 -0.756357     -0.810443     -0.267261
# 480     -1.229402      1.145410 -0.012231     -0.810443     -0.267261
# 621     -1.229402      1.199761 -0.005811      0.476731     -0.267261
# 645     -0.267261      1.851980 -0.162375     -0.810443     -0.267261
# 756      1.175949     -0.213380 -0.522753      0.476731     -0.267261
# 21       -0.404063        0.0       0.0  1.329424  1.404879
# 81       -0.404063        0.0       0.0  0.062561  1.404879
# 100      -0.404063        0.0       0.0  0.907136  0.561951
# 138      -0.404063        0.0       0.0  0.907136 -1.123903
# 151      -0.404063        0.0       0.0  0.062561 -1.123903
# 189      -0.404063        0.0       0.0  0.062561 -1.123903
# 190      -0.404063        0.0       0.0 -1.626589 -1.123903
# 227      -0.404063        0.0       0.0 -0.359726  0.561951
# 246      -0.404063        0.0       0.0 -0.359726 -1.123903
# 317      -0.404063        0.0       0.0  0.062561 -1.123903
# 429      -0.404063        0.0       0.0  1.329424  0.561951
# 458      -0.404063        0.0       0.0 -1.626589  2.247806
# 480      -0.404063        0.0       0.0 -2.471164 -0.280976
# 621      -0.404063        0.0       0.0  0.062561 -0.280976
# 645      -0.404063        0.0       0.0  0.062561 -0.280976
# 756      -0.404063        0.0       0.0  0.062561  0.561951
# 823       2.059416        0.0       0.0 -0.359726  2.247806
# 934       1.637105        0.0       0.0  1.329424 -0.280976
# 1087     -0.404063        0.0       0.0  0.062561  0.561951
# 1136     -0.404063        0.0       0.0  1.329424 -0.280976
# 1170     -0.404063        0.0       0.0  1.329424 -1.123903
# 1231     -0.404063        0.0       0.0  0.484849 -0.280976
# 1308      2.223648        0.0       0.0  0.484849  0.561951
# 1477     -0.404063        0.0       0.0 -1.626589 -0.280976
# 1592     -0.404063        0.0       0.0  0.062561 -1.123903
# 1613     -0.404063        0.0       0.0 -1.204302  0.561951
# 1964      3.373271        0.0       0.0 -0.359726 -0.280976
#
# [27 rows x 38 columns]

# %% [markdown]
# # Categorical Features

# %% [markdown]
# #### Ordinal Features

# %%
ordinal_columns = ['utilities','land_slope','exter_qual',
       'bsmt_qual', 'bsmt_cond', 'bsmt_exposure','bsmtfin_type_1',
        'bsmtfin_type_2', 'heating_qc','electrical', 'kitchen_qual', 
        'functional','fireplace_qu', 'garage_finish', 'garage_qual',
        'garage_cond', 'paved_drive']

# %%
ordinal_train_df = categorical_train_df[ordinal_columns]
ordinal_train_df.head()
# Out:
#     utilities land_slope exter_qual bsmt_qual bsmt_cond bsmt_exposure  \
# 21     AllPub        Gtl         Gd        Gd        TA            No
# 81     AllPub        Gtl         Ex        Ex        TA            No
# 100    AllPub        Gtl         Ex        Ex        TA            Gd
# 138    AllPub        Gtl         Ex        Ex        TA            Gd
# 151    AllPub        Gtl         Gd        Ex        TA            Av
#
#     bsmtfin_type_1 bsmtfin_type_2 heating_qc electrical kitchen_qual  \
# 21             GLQ            Unf         Ex      SBrkr           Ex
# 81             GLQ            Unf         Ex      SBrkr           Ex
# 100            GLQ            Unf         Ex      SBrkr           Ex
# 138            Unf            Unf         Ex      SBrkr           Ex
# 151            GLQ            Unf         Ex      SBrkr           Ex
#
#     functional fireplace_qu garage_finish garage_qual garage_cond paved_drive
# 21         Typ           Ex           Fin          TA          TA           Y
# 81         Typ           Gd           Fin          TA          TA           Y
# 100        Typ           Gd           Fin          TA          TA           Y
# 138        Typ           Ex           Fin          TA          TA           Y
# 151        Typ           Gd           Fin          TA          TA           Y

# %%
ordinal_null = ordinal_train_df.isna().sum().sort_values(ascending = False)
ordinal_null[ordinal_null > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# #### Ordinal categories that could mean 0 for NA

# %% [markdown]
# ## Nominal Features

# %%
nominal_train_df = categorical_train_df.drop(columns = ordinal_columns)
nominal_train_df.head()
# Out:
#     ms_zoning street lot_shape land_contour lot_config neighborhood  \
# 21         RL   Pave       IR1          Lvl     Inside      StoneBr
# 81         RL   Pave       IR1          Lvl    CulDSac      StoneBr
# 100        RL   Pave       IR1          HLS    CulDSac      StoneBr
# 138        RL   Pave       IR1          HLS    CulDSac      StoneBr
# 151        RL   Pave       IR1          Lvl     Inside      StoneBr
#
#     condition_1 condition_2 bldg_type house_style  ... roof_matl exterior_1st  \
# 21         Norm        Norm    TwnhsE      1Story  ...   CompShg      CemntBd
# 81         Norm        Norm      1Fam      1Story  ...   CompShg      VinylSd
# 100        Norm        Norm      1Fam      1Story  ...   CompShg      VinylSd
# 138        Norm        Norm      1Fam      2Story  ...   CompShg      CemntBd
# 151        Norm        Norm      1Fam      2Story  ...   CompShg      CemntBd
#
#     exterior_2nd mas_vnr_type exter_cond foundation heating central_air  \
# 21       CmentBd         None         TA      PConc    GasA           Y
# 81       VinylSd        Stone         TA      PConc    GasA           Y
# 100      VinylSd      BrkFace         TA      PConc    GasA           Y
# 138      CmentBd      BrkFace         TA      PConc    GasA           Y
# 151      CmentBd        Stone         TA      PConc    GasA           Y
#
#     garage_type sale_type
# 21       Attchd       WD
# 81       Attchd       New
# 100      Attchd       WD
# 138     BuiltIn       New
# 151     BuiltIn       New
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Nominal categories that could mean 0 for NA

# %% [markdown]
# ## Encoding Ordinal Features

# %% [markdown]
# ### Ordinal Dictionary

# %%
ordinal_col_list = ordinal_train_df.columns
print(ordinal_col_list)
# Out:
# Index(['utilities', 'land_slope', 'exter_qual', 'bsmt_qual', 'bsmt_cond',
#        'bsmt_exposure', 'bsmtfin_type_1', 'bsmtfin_type_2', 'heating_qc',
#        'electrical', 'kitchen_qual', 'functional', 'fireplace_qu',
#        'garage_finish', 'garage_qual', 'garage_cond', 'paved_drive'],
#       dtype='object')

# %%
ordinal_dict = [
    
#Utilities
{'AllPub':4,'NoSewr':3,'NoSeWa':2,'ELO':1},
#Land Slope
{'Gtl':3,'Mod':2,'Sev':1},
#Exter Qual
{'Ex':5,'Gd':4, 'TA':3, 'Fa':2,'Po':1},     
#Bsmt Qual
{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,0:0},
#Bsmt Cond
{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,0:0},
#Bsmt Exposure
{'Gd':4,'Av':3,'Mn':2,'No':1,0:0},
#BsmtFin Type 1
{'GLQ':6,'ALQ':5,'BLQ':4,'Rec':3,'LwQ':2,'Unf':1,0:0},
#BsmtFinType 2
{'GLQ':6,'ALQ':5,'BLQ':4,'Rec':3,'LwQ':2,'Unf':1,0:0},
#HeatingQC 
{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1},
#Electrical
{'SBrkr':5,'FuseA':4,'FuseF':3,'FuseP':2,'Mix':1},
#KitchenQual
{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1},
#Functional
{'Typ':8,'Min1':7,'Min2':6,'Mod':5,'Maj1':4,'Maj2':3,'Sev':2,'Sal':1},
#FireplaceQu
{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,0:0},
#Garage Finish
{'Fin':3,'RFn':2,'Unf':1,0:0},
#Garage Qual
{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,0:0},
#Garage Cond
{'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,0:0},
#Paved Drive
{'Y':3,'P':2,'N':1},

]

# %%
#zip column names to dictionary values
named_ordinal_dict = dict(zip(ordinal_col_list,ordinal_dict))

# %%
def ordinal_replace(df,columns):
    for column in columns:
        df[column] = df[column].map(named_ordinal_dict[column])
    return df

# %%
#replace categorty value with values
encoded_ordinal_train_df = ordinal_replace(ordinal_train_df, ordinal_train_df.columns)
encoded_ordinal_train_df
# Out:
#       utilities  land_slope  exter_qual  bsmt_qual  bsmt_cond  bsmt_exposure  \
# 21            4           3           4          4          3              1
# 81            4           3           5          5          3              1
# 100           4           3           5          5          3              4
# 138           4           3           5          5          3              4
# 151           4           3           4          5          3              3
# 189           4           3           5          5          4              1
# 190           4           3           4          5          3              4
# 227           4           3           4          4          4              1
# 246           4           3           4          4          4              1
# 317           4           3           4          5          4              4
# 429           4           3           4          4          3              1
# 458           4           3           4          4          3              1
# 480           4           3           4          5          4              4
# 621           4           3           4          5          3              4
# 645           4           3           4          5          3              2
# 756           4           3           5          5          3              4
# 823           4           2           5          4          3              4
# 934           4           3           5          5          3              4
# 1087          4           3           4          5          3              4
# 1136          4           3           4          4          3              3
# 1170          4           3           5          5          3              4
# 1231          4           3           4          4          3              4
# 1308          4           3           4          5          3              3
# 1477          4           3           4          5          3              4
# 1592          4           3           5          5          3              1
# 1613          4           2           4          4          3              4
# 1964          4           3           5          5          3              3
#
#       bsmtfin_type_1  bsmtfin_type_2  heating_qc  electrical  kitchen_qual  \
# 21                 6               1           5           5             5
# 81                 6               1           5           5             5
# 100                6               1           5           5             5
# 138                1               1           5           5             5
# 151                6               1           5           5             5
# 189                1               1           5           5             5
# 190                6               1           5           5             5
# 227                1               1           5           5             5
# 246                6               3           4           5             4
# 317                6               1           5           5             4
# 429                6               1           4           5             4
# 458                6               1           5           5             4
# 480                6               1           5           5             4
# 621                6               1           5           5             4
# 645                6               1           5           5             5
# 756                6               1           5           5             5
# 823                5               1           5           5             5
# 934                6               1           5           5             5
# 1087               6               1           5           5             5
# 1136               6               1           5           5             4
# 1170               1               1           5           5             4
# 1231               6               1           4           5             4
# 1308               6               1           5           5             5
# 1477               6               1           5           5             5
# 1592               6               1           5           5             5
# 1613               6               1           4           5             4
# 1964               6               1           5           5             4
#
#       functional  fireplace_qu  garage_finish  garage_qual  garage_cond  \
# 21             8             5              3            3            3
# 81             8             4              3            3            3
# 100            8             4              3            3            3
# 138            8             5              3            3            3
# 151            8             4              3            3            3
# 189            8             4              3            3            3
# 190            8             4              3            3            3
# 227            8             4              3            3            3
# 246            8             3              2            4            3
# 317            8             4              3            3            3
# 429            8             3              2            3            3
# 458            8             3              2            3            3
# 480            8             4              2            3            3
# 621            8             4              3            3            3
# 645            8             4              3            3            3
# 756            8             4              2            3            3
# 823            5             4              3            3            3
# 934            8             4              3            3            3
# 1087           8             4              3            3            3
# 1136           8             4              2            3            3
# 1170           8             4              3            3            3
# 1231           8             3              2            3            3
# 1308           8             4              3            3            3
# 1477           8             4              3            3            3
# 1592           8             4              2            3            3
# 1613           8             3              2            3            3
# 1964           8             4              3            4            3
#
#       paved_drive
# 21              3
# 81              3
# 100             3
# 138             3
# 151             3
# 189             3
# 190             3
# 227             3
# 246             3
# 317             3
# 429             3
# 458             3
# 480             3
# 621             3
# 645             3
# 756             3
# 823             3
# 934             3
# 1087            3
# 1136            3
# 1170            3
# 1231            3
# 1308            3
# 1477            3
# 1592            3
# 1613            3
# 1964            3

# %% [markdown]
# ### Encoding Nominal Features

# %%
#all 0 values replaced from NA should be dropped when encoded.
dummies_nominal_train_df = pd.get_dummies(nominal_train_df, drop_first=True)

# %% [markdown]
# ## Combine all dataframes back to one and save

# %%
#numerical, ordinal, and nominal data frames created earlier
dataframes = [scaled_numeric_train_df,encoded_ordinal_train_df,dummies_nominal_train_df]

# %%
#combine on index
cleaned_train_data = pd.concat(dataframes, axis=1)
cleaned_train_data.head()
# Out:
#        id        pid  ms_subclass  lot_frontage  lot_area  overall_qual  \
# 21    351  527131030     1.175949     -1.300412 -0.732817     -0.810443
# 81    367  527214050    -1.229402     -0.050326  0.273760      0.476731
# 100  1013  527214030    -1.229402     -0.593842  0.100676      0.476731
# 138  2331  527210040    -0.267261     -0.213380  0.328459      1.763906
# 151  2333  527212030    -0.267261      1.145410  0.156744      0.476731
#
#      overall_cond  year_built  year_remod/add  mas_vnr_area  ...  \
# 21      -0.267261   -0.423530       -0.475964     -0.998392  ...
# 81      -0.267261    0.921801        1.006847      1.373508  ...
# 100     -0.267261    0.249135        0.183063     -0.059779  ...
# 138     -0.267261    0.585468        0.512576      1.100803  ...
# 151     -0.267261    0.417302        0.512576     -0.338826  ...
#
#      exterior_2nd_HdBoard  exterior_2nd_MetalSd  exterior_2nd_VinylSd  \
# 21                      0                     0                     0
# 81                      0                     0                     1
# 100                     0                     0                     1
# 138                     0                     0                     0
# 151                     0                     0                     0
#
#      exterior_2nd_Wd Shng  mas_vnr_type_None  mas_vnr_type_Stone  \
# 21                      0                  1                   0
# 81                      0                  0                   1
# 100                     0                  0                   0
# 138                     0                  0                   0
# 151                     0                  0                   1
#
#      exter_cond_Gd  exter_cond_TA  garage_type_BuiltIn  sale_type_WD
# 21               0              1                    0              1
# 81               0              1                    0              0
# 100              0              1                    0              1
# 138              0              1                    1              0
# 151              0              1                    1              0
#
# [5 rows x 80 columns]

# %%
#combine target back to cleaned dataframe on ID
final_train_df = pd.merge(cleaned_train_data,y, on = 'id')

# %%
final_train_df.to_csv('datasets/train_stonebrook_df.csv',index=False)
